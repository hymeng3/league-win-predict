# %%
import requests

api_key = "RGAPI-9eb14ef9-8a0a-4837-b402-6b5fccc804a5"

# %%
summoner_url = "https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Hilberto%20Perkins"
summoner_url = summoner_url + '?api_key=' + api_key
resp = requests.get(summoner_url)
player_info = resp.json()
player_info
# Out:
# {'id': 'JGBljE3F23JXHpFIYa7kDpkrgaYjIwAq_ZFgjUXcdhu8Cc_q7lMlUX3tcQ',
#  'accountId': '8jBWzc8oxx-rxsQMX_zFDU_v-uAjybqpgfBzRU0sO0C_RpNO913c9Uz2',
#  'puuid': 'mIOnr3fXUPx3ZCNHkUU0ZrxWM2lV3ifb_70LiOPFiSqUI1bd89Qw6bvUp2SheAmqonnurgB41vwjMg',
#  'name': 'Hilberto Perkins',
#  'profileIconId': 907,
#  'revisionDate': 1698999052000,
#  'summonerLevel': 31}

# %%
summoner_matches_url = "https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/mIOnr3fXUPx3ZCNHkUU0ZrxWM2lV3ifb_70LiOPFiSqUI1bd89Qw6bvUp2SheAmqonnurgB41vwjMg/ids?start=0&count=20"
summoner_matches_url = summoner_matches_url + '&api_key=' + api_key
resp = requests.get(summoner_matches_url)
matches = resp.json()
matches[3]
# Out:
# 'NA1_4818379925'

# %%
match_url = "https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4818379925"
match_url = match_url + '?api_key=' + api_key
resp = requests.get(match_url)
match_info = resp.json()
match_info['info']['teams']
# Out:
# [{'bans': [{'championId': 54, 'pickTurn': 1},
#    {'championId': 28, 'pickTurn': 2},
#    {'championId': 115, 'pickTurn': 3},
#    {'championId': 233, 'pickTurn': 4},
#    {'championId': 133, 'pickTurn': 5}],
#   'objectives': {'baron': {'first': False, 'kills': 0},
#    'champion': {'first': True, 'kills': 18},
#    'dragon': {'first': True, 'kills': 2},
#    'horde': {'first': False, 'kills': 0},
#    'inhibitor': {'first': False, 'kills': 0},
#    'riftHerald': {'first': True, 'kills': 2},
#    'tower': {'first': False, 'kills': 3}},
#   'teamId': 100,
#   'win': False},
#  {'bans': [{'championId': 104, 'pickTurn': 6},
#    {'championId': 96, 'pickTurn': 7},
#    {'championId': 75, 'pickTurn': 8},
#    {'championId': 53, 'pickTurn': 9},
#    {'championId': 233, 'pickTurn': 10}],
#   'objectives': {'baron': {'first': True, 'kills': 2},
#    'champion': {'first': False, 'kills': 36},
#    'dragon': {'first': False, 'kills': 3},
#    'horde': {'first': False, 'kills': 0},
# ...

# %%
match_info['info']['participants'][0]
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 3,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 170,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 2,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 150,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 2,
#   'damagePerMinute': 283.76817516976126,
#   'damageTakenOnTeamPercentage': 0.26444912684446825,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 10,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 11,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
# ...
